# %%
import pandas as pd
from job_agents.skill_descriptions import write_descriptions

# %%
skills = [
    "python",
    "machine learning",
    "data analysis",
    "project management",
]

# %%
skill_description = await write_descriptions(skills, batch_size=2)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:04<00:00,  2.34s/it]
# JSON decode error: Expecting value: line 1 column 1 (char 0)

# %%
skill_description
# Out:
# {'data analysis': 'Data analysis involves the systematic examination of data sets to extract meaningful insights, trends, and patterns. This skill is crucial for making informed decisions, improving processes, and tailoring strategies based on empirical evidence.',
#  'project management': 'Project management encompasses the planning, execution, and monitoring of projects to achieve specific goals within defined constraints, such as time, budget, and resources. It requires skills in leadership, organization, and communication to coordinate teams and ensure successful project outcomes.'}
