# %%
import pandas as pd
from translate_titles import translate_titles_to_en, translate_titles_from_en

# %% [markdown]
# ### 1. Translate titles to english

# %%
titles_lt = [
        "Vyriausiasis (-ioji) teisininkas (-ė",
        "Vyriausiasis teisininkas (-ė) Licencijų administravimo skyriuje",
        "VYRESNIOJI (-YSIS) TEISININKĖ (-AS) (KORPORATYVINĖ IR ĮMONIŲ TEISĖ",
        "Teisininkas (-ė",
        "Inovacijų ekspertas (-ė",
        "Informacinių sistemų saugos pareigūnas (-ė) (įgaliotinis (-ė)) 0,5 et. darbo krūviu",
        "Strateginio planavimo skyriaus finansų planuotojo (-jos",
        "Komunikacijos skyriaus patarėjo(-jos",
        "Teisininkas (-ė",
        "TEISININKĖ (-AS) (GINČŲ TEISĖ"
    ]
translated_titles = await translate_titles_to_en(titles_lt, batch_size=2) # for notebook
print(translated_titles)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  2.78it/s]
# ['Chief Lawyer', 'Chief Lawyer in the Licensing Administration Department', 'Senior Attorney (Corporate and Business Law)', 'Lawyer', 'Innovation Expert', 'Information Systems Security Officer (Authorized Representative) (0.5 FTE workload)', 'Financial Planner of the Strategic Planning Department', 'Advisor of the Communications Department', 'Lawyer', 'Lawyer (Dispute Law)']

# %% [markdown]
# ### 2. Translate english titles to other language

# %%
titles_en = [
    "Account management",
    "Warehouseman / picker",
    "Service and sales representatives Customer service representatives",
    "Secretaries / Clerks | receptionists",
    "Telephone sales representatives Service and sales representatives",
    "full time position",
    "Back Office",
    "warehouseman",
    "Account management full time position",
    "Secretaries / Clerks | full time position",
    ]
translated_titles = await translate_titles_from_en(titles=titles_en, to_lang_code="fr", batch_size=2) # for notebook
print(translated_titles)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:06<00:00,  1.36s/it]
# ['Gestion des comptes', 'Magasinier / préparateur de commandes', 'Représentants de service et de ventes Représentants du service clientèle', 'Secrétaires / Employés de bureau | Réceptionnistes', 'Représentants de vente par téléphone', 'poste à temps plein', 'Back Office', 'Magasinier', 'Poste à temps plein en gestion de comptes', 'Secrétaires / Employés de bureau | poste à temps plein']
