# %%
import pandas as pd
from translate_titles import translate_titles_to_en, translate_titles_from_en

# %% [markdown]
# ### 1. Translate titles to english

# %%
titles_lt = [
        "Vyriausiasis (-ioji) teisininkas (-ė",
        "Vyriausiasis teisininkas (-ė) Licencijų administravimo skyriuje",
        "VYRESNIOJI (-YSIS) TEISININKĖ (-AS) (KORPORATYVINĖ IR ĮMONIŲ TEISĖ",
        "Teisininkas (-ė",
        "Inovacijų ekspertas (-ė",
        "Informacinių sistemų saugos pareigūnas (-ė) (įgaliotinis (-ė)) 0,5 et. darbo krūviu",
        "Strateginio planavimo skyriaus finansų planuotojo (-jos",
        "Komunikacijos skyriaus patarėjo(-jos",
        "Teisininkas (-ė",
        "TEISININKĖ (-AS) (GINČŲ TEISĖ"
    ]
translated_titles = await translate_titles_to_en(titles_lt, batch_size=2) # for notebook
print(translated_titles)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  2.78it/s]
# ['Chief Lawyer', 'Chief Lawyer in the Licensing Administration Department', 'Senior Attorney (Corporate and Business Law)', 'Lawyer', 'Innovation Expert', 'Information Systems Security Officer (Authorized Representative) (0.5 FTE workload)', 'Financial Planner of the Strategic Planning Department', 'Advisor of the Communications Department', 'Lawyer', 'Lawyer (Dispute Law)']

# %% [markdown]
# ### 2. Translate english titles to other language

# %%
titles_en = [
    "Account management",
    "Warehouseman / picker",
    "Service and sales representatives Customer service representatives",
    "Secretaries / Clerks | receptionists",
    "Telephone sales representatives Service and sales representatives",
    "full time position",
    "Back Office",
    "warehouseman",
    "Account management full time position",
    "Secretaries / Clerks | full time position",
    ]
translated_titles = await translate_titles_from_en(titles=titles_en, to_lang_code="fr", batch_size=2) # for notebook
print(translated_titles)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:06<00:00,  1.36s/it]
# ['Gestion des comptes', 'Magasinier / préparateur de commandes', 'Représentants de service et de ventes Représentants du service clientèle', 'Secrétaires / Employés de bureau | Réceptionnistes', 'Représentants de vente par téléphone', 'poste à temps plein', 'Back Office', 'Magasinier', 'Poste à temps plein en gestion de comptes', 'Secrétaires / Employés de bureau | poste à temps plein']

# %%
from segment_jobs import classify_job_description
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from segment_jobs import classify_job_description
#
# File ~/Documents/GitHub/LLM-for-Jobs/GPT-for-jobs/segment_jobs.py:8
#       5 from openai import AsyncOpenAI
#       6 import instructor
# ----> 8 aclient = instructor.patch(AsyncOpenAI())
#      10 class Labels(Enum):
#      11     COMPANY = "company"
#
# File /opt/miniconda3/envs/py312/lib/python3.12/site-packages/openai/_client.py:345, in AsyncOpenAI.__init__(self, api_key, organization, project, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     343     api_key = os.environ.get("OPENAI_API_KEY")
#     344 if api_key is None:
# --> 345     raise OpenAIError(
# ...

# %%
job = """
About the job
You have a passion for technology and want to make the world a greener place? 

Join the forefront of energy transition with E.ON's Digital Technology organization, as part of our technology in-house consulting, Expert Services. As a professional services organization, we collaborate closely with our business units, providing pivotal services that accelerate E.ON's ambitious Digital Transformation strategy.

If you have a passion for leading the green transition with digital innovation, become a playmaker in our energetic and diverse team of more than 500 Expert Services consultants.

It’s on us to make new energy work!

Your Role – meaningful & rewarding

You integrate and refine Generative AI techniques, such as large language models (LLM) and Retrieval Augmented Generation (RAG), for improved content generation and decision-making
You design, train, and optimize machine learning and deep learning models for various applications
You develop, maintain, and optimize software products that support scalable and efficient AI applications
You work closely with cross-functional teams to develop AI-driven solutions that leverage the power of AI
You build sustainable relationships with stakeholders and showcase our capabilities and projects at internal and external events and conferences on a regular basis.
You keep up with the latest advancements in AI, in particular Generative AI, to enhance projects and workflows, ensuring the effective integration of cutting-edge technologies


Your Profile – authentic & open-minded

With several years of experience, you have a strong track record developing and deploying data science & ML solutions for real-life use cases. You feel comfortable performing basic statistical inference as well as developing machine learning algorithms and confidently suggest the right solution for a given business problem. Experience working with LLMs and GenAI is a huge plus
You have previous experience in project teams and successfully solved data science challenges. Ideally, you provided guidance on how to model a certain business decision and how to build and deploy the solution using cloud services. Experience with MS Azure is a plus
With your strong python and SQL skills, you can create prototypes and effectively explore big and small data in all shapes. You have a solid foundation on how to collaboratively work on production-grade software
You’re a self-starter who is comfortable working autonomously and with teams located across our offices. You have a strong hands-on mentality, prioritize your focus based on impact, and are able to own a project from start to finish


Our Benefits – smart & useful

Enjoy flexibility: You can combine coming to the office and working from home flexibly. It’s even possible to go on workation for up to 20 days per year within Europe. 
Advance your development: We grow and we want you to grow with us. Learning on the job, exchanging with others, or taking part in an individual training – our learning culture enables you to bring your personal and professional development to the next level. 
Get connected: Take the opportunity to engage in our Digital Empowerment Communities for collaboration, learning, and network building. 
Recharge your battery: You have 30 days of paid vacation per year plus Christmas and New Year's Eve off. Your battery still needs charging? You can exchange parts of your salary for more paid vacation or you can take a sabbatical. 
Elevate your mobility: From car and bike leasing offers to a subsidised Deutschland-Ticket – your way is our way. 
Think ahead: With our company pension scheme and a great insurance package we take care of your future. 
This is by far not all… We are looking forward to speaking with you about further benefits during the hiring process.

"""

# %%
from openai import OpenAI
client = OpenAI()

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": "Write a one-sentence bedtime story about a unicorn."
        }
    ]
)

print(completion.choices[0].message.content)
# Out:
# As the moonlight shimmered through the forest, a gentle unicorn named Lila spread her sparkling wings and flew high above the trees, granting sweet dreams to every child below.
